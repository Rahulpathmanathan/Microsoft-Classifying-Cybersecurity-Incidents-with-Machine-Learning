# %%
import pandas as pd

# %%
df_train = pd.read_csv("GUIDE_Train.csv")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9516837 entries, 0 to 9516836
# Data columns (total 45 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  int64
#  1   OrgId               int64
#  2   IncidentId          int64
#  3   AlertId             int64
#  4   Timestamp           object
#  5   DetectorId          int64
#  6   AlertTitle          int64
#  7   Category            object
#  8   MitreTechniques     object
#  9   IncidentGrade       object
#  10  ActionGrouped       object
#  11  ActionGranular      object
#  12  EntityType          object
#  13  EvidenceRole        object
#  14  DeviceId            int64
#  15  Sha256              int64
#  16  IpAddress           int64
#  17  Url                 int64
#  18  AccountSid          int64
#  19  AccountUpn          int64
#  20  AccountObjectId     int64
#  21  AccountName         int64
#  22  DeviceName          int64
#  23  NetworkMessageId    int64
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df_train.head(10)
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0   180388628218      0         612   123247  2024-06-04T06:05:15.000Z
# 1   455266534868     88         326   210035  2024-06-14T03:01:25.000Z
# 2  1056561957389    809       58352   712507  2024-06-13T04:52:55.000Z
# 3  1279900258736     92       32992   774301  2024-06-10T16:39:36.000Z
# 4   214748368522    148        4359   188041  2024-06-15T01:08:07.000Z
# 5  1322849927433     11      417400   825450  2024-06-10T13:30:56.000Z
# 6   163208760309    522         566   705663  2024-06-14T23:19:45.000Z
# 7  1400159339557    125       38679    47423  2024-06-06T13:39:23.000Z
# 8  1219770713645     21         414   197969  2024-06-09T10:21:29.000Z
# 9  1073741827836     72          70   831157  2024-06-08T02:08:01.000Z
#
#    DetectorId  AlertTitle            Category  MitreTechniques  \
# 0           7           6       InitialAccess              NaN
# ...

# %%
df_train.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9516837 entries, 0 to 9516836
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Timestamp          object
#  1   Category           object
#  2   MitreTechniques    object
#  3   IncidentGrade      object
#  4   ActionGrouped      object
#  5   ActionGranular     object
#  6   EntityType         object
#  7   EvidenceRole       object
#  8   ThreatFamily       object
#  9   ResourceType       object
#  10  Roles              object
#  11  AntispamDirection  object
#  12  SuspicionLevel     object
#  13  LastVerdict        object
# dtypes: object(14)
# memory usage: 1016.5+ MB

# %%
df_train.select_dtypes(include='object')
# Out:
#                         Timestamp           Category MitreTechniques  \
# 0        2024-06-04T06:05:15.000Z      InitialAccess             NaN
# 1        2024-06-14T03:01:25.000Z       Exfiltration             NaN
# 2        2024-06-13T04:52:55.000Z      InitialAccess           T1189
# 3        2024-06-10T16:39:36.000Z  CommandAndControl             NaN
# 4        2024-06-15T01:08:07.000Z          Execution             NaN
# ...                           ...                ...             ...
# 9516832  2024-06-08T15:26:08.000Z      InitialAccess             NaN
# 9516833  2024-06-06T09:40:08.000Z  CommandAndControl             NaN
# 9516834  2024-06-11T22:51:03.000Z       Exfiltration             NaN
# 9516835  2024-05-20T23:01:01.000Z             Impact             NaN
# 9516836  2024-06-03T23:51:52.000Z       Exfiltration             NaN
#
#           IncidentGrade ActionGrouped ActionGranular         EntityType  \
# ...

# %%
df_train.select_dtypes(include='object').isnull().sum()
# Out:
# Timestamp                  0
# Category                   0
# MitreTechniques      5468386
# IncidentGrade          51340
# ActionGrouped        9460773
# ActionGranular       9460773
# EntityType                 0
# EvidenceRole               0
# ThreatFamily         9441956
# ResourceType         9509762
# Roles                9298686
# AntispamDirection    9339535
# SuspicionLevel       8072708
# LastVerdict          7282572
# dtype: int64

# %%
df_train["Category"].value_counts()
# Out:
# Category
# InitialAccess          4293041
# Exfiltration           1577965
# SuspiciousActivity     1003933
# CommandAndControl       826691
# Impact                  750885
# CredentialAccess        300518
# Execution               267594
# Malware                 144081
# Discovery               129342
# Persistence              72682
# DefenseEvasion           46662
# LateralMovement          41754
# Ransomware               18974
# UnwantedSoftware         18211
# Collection               14753
# PrivilegeEscalation       4671
# Exploit                   4648
# CredentialStealing         388
# WebExploit                  38
# Weaponization                6
# Name: count, dtype: int64

# %%
df_train['hour'] = pd.to_datetime(df_train['Timestamp']).dt.hour
df_train.groupby('hour')['IncidentGrade'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='hour'>

# %%
df_train.drop(["MitreTechniques","ActionGrouped","ActionGranular","ThreatFamily","ResourceType","Roles","AntispamDirection","SuspicionLevel","LastVerdict"],axis=1,inplace=True)

# %%
df_train.select_dtypes(include='int')
# Out:
#                     Id  OrgId  IncidentId  AlertId  DetectorId  AlertTitle  \
# 0         180388628218      0         612   123247           7           6
# 1         455266534868     88         326   210035          58          43
# 2        1056561957389    809       58352   712507         423         298
# 3        1279900258736     92       32992   774301           2           2
# 4         214748368522    148        4359   188041           9          74
# ...                ...    ...         ...      ...         ...         ...
# 9516832  1056561956622      0          90   496631           7           6
# 9516833  1228360650033     59      196410   748366           2           2
# 9516834   867583395122     44       14117     7425          78          57
# 9516835   395136991850     43         644     8973          52          10
# 9516836   678604833923     16      141721   644106          24         348
#
# ...

# %%
df_train.select_dtypes(include='float').isnull().sum()
# Out:
# EmailClusterId    9420025
# dtype: int64

# %%
df_train.drop(["EmailClusterId"],axis=1,inplace=True)

# %%
df_train.select_dtypes(include='int')
# Out:
#                     Id  OrgId  IncidentId  AlertId  DetectorId  AlertTitle  \
# 0         180388628218      0         612   123247           7           6
# 1         455266534868     88         326   210035          58          43
# 2        1056561957389    809       58352   712507         423         298
# 3        1279900258736     92       32992   774301           2           2
# 4         214748368522    148        4359   188041           9          74
# ...                ...    ...         ...      ...         ...         ...
# 9516832  1056561956622      0          90   496631           7           6
# 9516833  1228360650033     59      196410   748366           2           2
# 9516834   867583395122     44       14117     7425          78          57
# 9516835   395136991850     43         644     8973          52          10
# 9516836   678604833923     16      141721   644106          24         348
#
# ...

# %%
df_train.select_dtypes(include='int').columns
# Out:
# Index(['Id', 'OrgId', 'IncidentId', 'AlertId', 'DetectorId', 'AlertTitle',
#        'DeviceId', 'Sha256', 'IpAddress', 'Url', 'AccountSid', 'AccountUpn',
#        'AccountObjectId', 'AccountName', 'DeviceName', 'NetworkMessageId',
#        'RegistryKey', 'RegistryValueName', 'RegistryValueData',
#        'ApplicationId', 'ApplicationName', 'OAuthApplicationId', 'FileName',
#        'FolderPath', 'ResourceIdName', 'OSFamily', 'OSVersion', 'CountryCode',
#        'State', 'City', 'hour'],
#       dtype='object')

# %%
df_train.select_dtypes(include='int').isnull().sum()
# Out:
# Id                    0
# OrgId                 0
# IncidentId            0
# AlertId               0
# DetectorId            0
# AlertTitle            0
# DeviceId              0
# Sha256                0
# IpAddress             0
# Url                   0
# AccountSid            0
# AccountUpn            0
# AccountObjectId       0
# AccountName           0
# DeviceName            0
# NetworkMessageId      0
# RegistryKey           0
# RegistryValueName     0
# RegistryValueData     0
# ApplicationId         0
# ApplicationName       0
# OAuthApplicationId    0
# FileName              0
# FolderPath            0
# ResourceIdName        0
# OSFamily              0
# OSVersion             0
# CountryCode           0
# State                 0
# City                  0
# hour                  0
# dtype: int64

# %%
df_train.drop(["Id","IncidentId","AlertId","DetectorId","AlertTitle","DeviceId","Sha256","IpAddress","Url","ApplicationName","OAuthApplicationId","FileName","FolderPath","ResourceIdName","OSFamily","OSVersion","CountryCode","State","City"],axis=1,inplace=True)

# %%
df_train.drop(["AccountSid","AccountUpn","AccountObjectId","AccountName","DeviceName","NetworkMessageId","RegistryKey","RegistryValueName","RegistryValueData","ApplicationId"],axis=1,inplace=True)

# %%
df_train.drop(["Timestamp"],axis=1,inplace = True)

# %%
df_train
# Out:
#          OrgId           Category   IncidentGrade         EntityType  \
# 0            0      InitialAccess    TruePositive                 Ip
# 1           88       Exfiltration   FalsePositive               User
# 2          809      InitialAccess   FalsePositive                Url
# 3           92  CommandAndControl  BenignPositive                Url
# 4          148          Execution    TruePositive               User
# ...        ...                ...             ...                ...
# 9516832      0      InitialAccess    TruePositive  CloudLogonRequest
# 9516833     59  CommandAndControl  BenignPositive                Url
# 9516834     44       Exfiltration  BenignPositive        MailMessage
# 9516835     43             Impact  BenignPositive                 Ip
# 9516836     16       Exfiltration  BenignPositive        MailMessage
#
#         EvidenceRole  hour
# 0            Related     6
# 1           Impacted     3
# 2            Related     4
# ...

# %%
df_train.to_csv("Final_train.csv",index=False)

# %%
# df_train.select_dtypes(include=object).columns
# Out:
# Index(['Category', 'IncidentGrade', 'EntityType', 'EvidenceRole'], dtype='object')

# %%
# for i in df_train.select_dtypes(include=object).columns:
#     print(i,len(df_train[i].unique()))
# Out:
# Category 20
# IncidentGrade 4
# EntityType 33
# EvidenceRole 2

# %%
# df_train['IncidentGrade'].value_counts()
# Out:
# IncidentGrade
# BenignPositive    4110817
# TruePositive      3322713
# FalsePositive     2031967
# Name: count, dtype: int64

# %%
# from sklearn.preprocessing import LabelEncoder

# %%
# encoders_train={}
# for col in df_train.select_dtypes(include=object).columns:
#     le=LabelEncoder()
#     df_train[col] = le.fit_transform(df_train[col])
#     encoders_train[col]=le

# %%
# encoders_train['IncidentGrade'].classes_
# Out:
# array(['BenignPositive', 'FalsePositive', 'TruePositive', nan],
#       dtype=object)

# %%
# encoders_train['Category']
# Out:
# LabelEncoder()

# %%
# df_train['IncidentGrade'].unique()
# Out:
# array([2, 1, 0, 3])
