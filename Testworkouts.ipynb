# %%
import pandas as pd

# %%
df_test = pd.read_csv("GUIDE_Test.csv")
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_23200\1483317521.py:1: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_test = pd.read_csv("GUIDE_Test.csv")

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4147992 entries, 0 to 4147991
# Data columns (total 46 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  int64
#  1   OrgId               int64
#  2   IncidentId          int64
#  3   AlertId             int64
#  4   Timestamp           object
#  5   DetectorId          int64
#  6   AlertTitle          int64
#  7   Category            object
#  8   MitreTechniques     object
#  9   IncidentGrade       object
#  10  ActionGrouped       object
#  11  ActionGranular      object
#  12  EntityType          object
#  13  EvidenceRole        object
#  14  DeviceId            int64
#  15  Sha256              int64
#  16  IpAddress           int64
#  17  Url                 int64
#  18  AccountSid          int64
#  19  AccountUpn          int64
#  20  AccountObjectId     int64
#  21  AccountName         int64
#  22  DeviceName          int64
#  23  NetworkMessageId    int64
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df_test.head(10)
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0  1245540519230    657       11767    87199  2024-06-04T22:56:27.000Z
# 1  1400159342154      3       91158   632273  2024-06-03T12:58:26.000Z
# 2  1279900255923    145       32247   131719  2024-06-08T03:20:49.000Z
# 3    60129547292    222       15294   917686  2024-06-12T12:07:31.000Z
# 4   515396080539    363        7615     5944  2024-06-06T17:42:05.000Z
# 5   670014899930      0         238   378946  2024-06-06T08:10:50.000Z
# 6  1194000913330    133      105333   732769  2024-06-15T04:06:55.000Z
# 7   678604832796      6        2461     1523  2024-05-26T11:48:38.000Z
# 8   618475292265      7        5177     1815  2024-05-25T17:57:20.000Z
# 9   438086667998    100        7060     9787  2024-06-02T05:46:22.000Z
#
#    DetectorId  AlertTitle            Category  \
# 0         524         563     LateralMovement
# 1           2           2   CommandAndControl
# ...

# %%
df_test['hour'] = pd.to_datetime(df_test['Timestamp']).dt.hour

# %%
df_test.drop(["MitreTechniques","ActionGrouped","ActionGranular","ThreatFamily","ResourceType","Roles","AntispamDirection","SuspicionLevel","LastVerdict","EmailClusterId"],axis=1,inplace=True)

# %%
df_test.drop(["Id","IncidentId","AlertId","DetectorId","AlertTitle","DeviceId","Sha256","IpAddress","Url","ApplicationName","OAuthApplicationId","FileName","FolderPath","ResourceIdName","OSFamily","OSVersion","CountryCode","State","City"],axis=1,inplace=True)

# %%
df_test.drop(["AccountSid","AccountUpn","AccountObjectId","AccountName","DeviceName","NetworkMessageId","RegistryKey","RegistryValueName","RegistryValueData","ApplicationId","Timestamp"],axis=1,inplace=True)

# %%
df_test.drop(["Usage"],axis=1,inplace=True)

# %%
df_test
# Out:
#          OrgId           Category   IncidentGrade         EntityType  \
# 0          657    LateralMovement  BenignPositive               User
# 1            3  CommandAndControl  BenignPositive            Machine
# 2          145    LateralMovement  BenignPositive            Process
# 3          222      InitialAccess   FalsePositive  CloudLogonSession
# 4          363          Discovery  BenignPositive               User
# ...        ...                ...             ...                ...
# 4147987    262      InitialAccess  BenignPositive               User
# 4147988   1323      InitialAccess  BenignPositive               User
# 4147989     47  CommandAndControl   FalsePositive                 Ip
# 4147990     70      InitialAccess  BenignPositive            Mailbox
# 4147991    227      InitialAccess    TruePositive            Mailbox
#
#         EvidenceRole  hour
# 0           Impacted    22
# 1           Impacted    12
# 2            Related     3
# ...

# %%
df_test.to_csv("Final_test.csv",index=False)

# %%
df_test
# Out:
#          OrgId           Category   IncidentGrade         EntityType  \
# 0          657    LateralMovement  BenignPositive               User
# 1            3  CommandAndControl  BenignPositive            Machine
# 2          145    LateralMovement  BenignPositive            Process
# 3          222      InitialAccess   FalsePositive  CloudLogonSession
# 4          363          Discovery  BenignPositive               User
# ...        ...                ...             ...                ...
# 4147987    262      InitialAccess  BenignPositive               User
# 4147988   1323      InitialAccess  BenignPositive               User
# 4147989     47  CommandAndControl   FalsePositive                 Ip
# 4147990     70      InitialAccess  BenignPositive            Mailbox
# 4147991    227      InitialAccess    TruePositive            Mailbox
#
#         EvidenceRole  hour
# 0           Impacted    22
# 1           Impacted    12
# 2            Related     3
# ...
